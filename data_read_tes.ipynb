# %%
import pandas as pd
import os
from pathlib import Path

# %%
root_path = os.getcwd()

# %%
file_path = Path(root_path).joinpath('data', 'raw', 'slchbs_saintlucia_2025_6_STATA_All', 'slchbs_saintlucia_2025_6', 'slchbs_saintlucia_2025.dta')
df_test = pd.read_stata(file_path, convert_categoricals=False)
